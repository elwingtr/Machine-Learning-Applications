# %% [markdown]
# # Exercise 3: Exploratory Data Analysis
# -------------------------------------
#
# The task in this exercise is to perform an exploratory data analysis on the iris flower dataset. This is one of the most commonly used classification datasets in the statistics and machine learning literature. It was published in 1936 and used in the paper *The use of multiple measurements in taxonomic problems* by R. A. Fisher.
#
# The dataset available in Moodle is taken from the UCI Machine Learning Repository: [Link to Iris Data set](http://archive.ics.uci.edu/dataset/53/iris)
#
# Download the dataset from Moodle. The dataset consists of two files:
# - bezdekIris.data: contains the data
# - iris.names: contains information about the dataset
#
# The iris dataset contains measurements of three different types of iris plants: iris setosa, iris versicolor and iris virginica. The measured features are the sepal length, sepal width, petal length and petal width of the flowers. The goal of the classification task is to distinguish the three iris types based on the given measurement data.
#
# | iris setosa                                           | iris versicolor                                           | iris virginica                                           |
# |-------------------------------------------------------|-----------------------------------------------------------|----------------------------------------------------------|
# | <img src="iris_images/Iris_setosa.jpg" width="250" /> | <img src="iris_images/Iris_versicolor.jpg" width="250" /> | <img src="iris_images/Iris_virginica.jpg" width="250" /> |

# %% [markdown]
# ------------------------
#
# ## Task 1: Load data
# Load the dataset into a *Pandas* DataFrame and inspect the DataFrame. How many instances does the dataset contain? Is the number of instances per class balanced across the three different classes?

# %%
import pandas as pd

# Veri dosyasının konumu
data_path = r"C:\Users\bbayr\Desktop\Dersler\Machine Learning Applications\Exercise\Exercise III Exploratory Data Analysis\Data_iris-20241111\bezdekIris.data"

# Sütun isimlerini belirleme
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# Veriyi yükleme
df = pd.read_csv(data_path, header=None, names=column_names)

# Veri çerçevesinin ilk satırlarına bakma
print("Veri çerçevesinin ilk satırları:")
print(df.head())

# Toplam örnek sayısı
print("\nToplam örnek sayısı:", len(df))

# Her sınıftaki örnek sayısı
print("\nHer sınıfın örnek sayıları:")
print(df['class'].value_counts())
# Out:
# Veri çerçevesinin ilk satırları:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
# Toplam örnek sayısı: 150
#
# Her sınıfın örnek sayıları:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## Task 2: Descriptive Statistics
#
# Calculate basic statistical properties of the four features. There are many built-in functions in *Pandas* to compute these properties. For example, you can use the *Pandas* *describe()* function. Plot the distributions of the features, e.g. using boxplots or histograms. What do you notice?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Veri dosyasının konumu
data_path = r"C:\Users\bbayr\Desktop\Dersler\Machine Learning Applications\Exercise\Exercise III Exploratory Data Analysis\Data_iris-20241111\bezdekIris.data"

# Sütun isimlerini belirleme
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# Veriyi yükleme
df = pd.read_csv(data_path, header=None, names=column_names)

# Temel istatistikleri hesaplama
print("Temel İstatistikler:")
print(df.describe())

# Özellik dağılımlarını çizme
plt.figure(figsize=(14, 10))

# Histogramlar
for i, column in enumerate(column_names[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    
plt.tight_layout()
plt.show()

# Boxplotlar
plt.figure(figsize=(14, 10))
for i, column in enumerate(column_names[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(y=df[column])
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()
# Out:
# Temel İstatistikler:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Task 3: Class investigation
#
# Take another look at the feature distributions and examine how the distribution of data differs between the different classes of iris setosa, iris versicolor and iris virginica.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Veri dosyasının konumu
data_path = r"C:\Users\bbayr\Desktop\Dersler\Machine Learning Applications\Exercise\Exercise III Exploratory Data Analysis\Data_iris-20241111\bezdekIris.data"

# Sütun isimlerini belirleme
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# Veriyi yükleme
df = pd.read_csv(data_path, header=None, names=column_names)

# Her sınıf için dağılımları çizme
plt.figure(figsize=(15, 10))

for i, feature in enumerate(column_names[:-1]):
    plt.subplot(2, 2, i + 1)
    sns.histplot(data=df, x=feature, hue='class', kde=True, element='step')
    plt.title(f'{feature} distribution by class')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 4: Correlation Analysis
#
# Analyze the relationship between the different features. This is done by performing a correlation analysis and visualizing the relationship using pairplots. Pairplots can for example be created using the *seaborn* library. What conclusions or hypotheses can be drawn from the analysis?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Veri dosyasının konumu
data_path = r"C:\Users\bbayr\Desktop\Dersler\Machine Learning Applications\Exercise\Exercise III Exploratory Data Analysis\Data_iris-20241111\bezdekIris.data"

# Sütun isimlerini belirleme
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# Veriyi yükleme
df = pd.read_csv(data_path, header=None, names=column_names)

# Korelasyon matrisini hesaplama (class sütununu hariç tutarak)
correlation_matrix = df.drop(columns=['class']).corr()

print("Korelasyon Matrisi:")
print(correlation_matrix)

# Korelasyon matrisini ısı haritası ile görselleştirme
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True, fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()

# Pairplot ile özellikler arasındaki ilişkileri sınıflara göre görselleştirme
sns.pairplot(df, hue='class', diag_kind='kde', markers=["o", "s", "D"])
plt.suptitle("Pairplot of Features by Class", y=1.02)
plt.show()
# Out:
# Korelasyon Matrisi:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ## Task 5: Classification
#
# Use a k-Nearest-Neighbor classifier to perform a classification on the iris data set. Choose an appropriate value for k. Compare the predicted results with the true values and evaluate the results using a confusion matrix. Are the results as expected based on the exploratory data analysis?
#
# For this task, you do not need to optimize the classifier using separate training and test sets. You can use the entire data set for training. The goal is simply to learn a classifier and get a first impression of how well the classification works.

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Veriyi yükleyelim (veri yolu ve sütun isimlerini kullanarak)
data_path = r'C:\Users\bbayr\Desktop\Dersler\Machine Learning Applications\Exercise\Exercise III Exploratory Data Analysis\Data_iris-20241111\bezdekIris.data'
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df = pd.read_csv(data_path, header=None, names=column_names)

# Sınıflandırıcı için veriyi hazırlama
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]  # Özellikler
y = df['class']  # Etiketler

# k-NN sınıflandırıcısını oluşturuyoruz (k=3 seçiyoruz)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)  # Modeli eğitiyoruz

# Tahminler yapalım
y_pred = knn.predict(X)

# Confusion Matrix
cm = confusion_matrix(y, y_pred)

# Confusion Matrix'i görselleştirelim
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=df['class'].unique(), yticklabels=df['class'].unique())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix for k-NN Classifier')
plt.show()

# Detaylı sınıflandırma raporu
print("Classification Report:")
print(classification_report(y, y_pred))
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        50
# Iris-versicolor       0.94      0.94      0.94        50
#  Iris-virginica       0.94      0.94      0.94        50
#
#        accuracy                           0.96       150
#       macro avg       0.96      0.96      0.96       150
#    weighted avg       0.96      0.96      0.96       150
